# %%
import os
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Compare results (2 test samples) between:
# - Baseline : word_to_job API
# - Model TermSum

# %% [markdown]
# ### Sample 1

# %%
# Load results
with open('../word_to_job_res/word_to_job_results_libelle.json') as f:
    wordtojob = json.load(f)
    
with open('../experiments/base_model_w3_e100/results_term_sum.json') as f:
    term_sum = json.load(f)

# %%
for el in wordtojob.keys():
    print("Compétence libre:\n{}\n--\nWord to Job:\n{}\n-\nTerm Sum:\n{}\n".format(el, wordtojob[el], term_sum[el]))
# Out:
# Compétence libre:
# Hungarian
# --
# Word to Job:
# []
# -
# Term Sum:
# []
#
# Compétence libre:
# evolia
# --
# Word to Job:
# []
# -
# Term Sum:
# ['Navire Transbordeur (car ferry)', 'Naviguer sur un yacht de plaisance à moteur', 'Naviguer sur un yacht de plaisance à voile']
#
# Compétence libre:
# Eplucher
# --
# Word to Job:
# ['Éplucher des légumes et des fruits', "Réaliser des garnitures d'articles de chapellerie", 'Réaliser des garnitures de siège']
# -
# Term Sum:
# ['Cuire des viandes, poissons ou légumes']
#
# Compétence libre:
# Filtre a air
# --
# Word to Job:
# ["Effectuer les manoeuvres d'accrochage/décrochage d'avions au véhicule de tractage et convoyer des aéronefs sur l'aire de roulement", 'Vérifier la sécurisation des aires de roulement ou de stationnement des aéronefs', "Surveiller l'application des arrêtés du maire et des règlements sur les terrains/aires d'accueil des gens du voyage"]
# -
# Term Sum:
# []
#
# Compétence libre:
# COMMUNICATION SAV
# --
# ...

# %% [markdown]
# ### Sample 2

# %%
# Load results
with open('../word_to_job_res/word_to_job_results_libelle_2.json') as f:
    wordtojob = json.load(f)
    
with open('../experiments/base_model_w3_e100/results_term_sum_2.json') as f:
    term_sum = json.load(f)

# %%
for el in wordtojob.keys():
    print("Compétence libre:\n{}\n--\nWord to Job:\n{}\n-\nTerm Sum:\n{}\n".format(el, wordtojob[el], term_sum[el]))
# Out:
# Compétence libre:
# PAVE
# --
# Word to Job:
# ['Implanter des pavés ou des dalles', 'Couper à dimension des bordures de trottoirs', 'Installer des bordures de trottoirs']
# -
# Term Sum:
# []
#
# Compétence libre:
# ? Brasage
# --
# Word to Job:
# ["Réaliser le soudage (à l'arc, brasage, ...) de pièces, organes mécaniques, ...", 'Procédés de brasage', 'Réaliser une opération de soudage, brasage']
# -
# Term Sum:
# ['Réaliser des prestations de rasage et taille de moustaches et barbes', 'Techniques de soudure MIG-MAG']
#
# Compétence libre:
# Tenir un food truck
# --
# Word to Job:
# ['Tenir à jour le registre du personnel', "Tenir informé un public sur les avancées d'un chantier", 'Tenir à jour le cahier de laboratoire']
# -
# Term Sum:
# []
#
# Compétence libre:
# Agora Project
# --
# Word to Job:
# ...
